# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhildongare123/Deep_Learning/blob/main/foocus_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.15.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 87.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.19.0
#     Uninstalling pygit2-1.19.0:
#       Successfully uninstalled pygit2-1.19.0
# ...

# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/lllyasviel/Fooocus.git
# Out:
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6730, done.
# remote: Total 6730 (delta 0), reused 0 (delta 0), pack-reused 6730 (from 1)
# Receiving objects: 100% (6730/6730), 33.35 MiB | 10.06 MiB/s, done.
# Resolving deltas: 100% (3848/3848), done.

# %%
# %cd /content/Fooocus/
# Out:
# /content/Fooocus

# %%
# !python entry_with_update.py --share --always-high-vram
# Out:
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# Fooocus version: 2.5.5
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Total VRAM 15095 MB, total RAM 12976 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# Running on local URL:  http://127.0.0.1:7865
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# model_type EPS
# UNet ADM Dimension 2816
# Running on public URL: https://775aa15471d6f14798.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Using pytorch attention in VAE
# ...

# %%
# !git clone https://github.com/lllyasviel/FramePack.git
# Out:
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6730, done.
# remote: Total 6730 (delta 0), reused 0 (delta 0), pack-reused 6730 (from 1)
# Receiving objects: 100% (6730/6730), 33.35 MiB | 16.82 MiB/s, done.
# Resolving deltas: 100% (3848/3848), done.
